# %% [markdown]
# This Notebook is created for the use in Battle of the Neighborhoods project

# %% [markdown]
# This Notebook is used for the CAPSTONE PROJECT.

# %%
import pandas as pd

# %%
import numpy as np

# %%
print ("HELLO CAPSTONE PROJECT COURSE!!!")
# Out:
# HELLO CAPSTONE PROJECT COURSE!!!
