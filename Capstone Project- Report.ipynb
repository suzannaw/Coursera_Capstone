# %% [markdown]
# # CAPSTONE PROJECT- THE BATTLE OF NEIGHBORHOODS (WEEK 2)

# %% [markdown]
# # Detailed Report

# %% [markdown]
# -  ## Introduction
#
# -  ## Business Problem
#
# -  ## Background
#
# -  ## Data Description
#
# -  ## Methodology
#
# -  ## Analysis and Results
#
# -  ## Conclusion

# %% [markdown]
# ## INTRODUCTION:

# %% [markdown]
#  This project is a part of the Capstone Datascience course which is used to put into use all our knowledge into doing a project by analysing data and making use of all the techniques learnt to address a real world problem and analyse and bring out the results.
#
#  This report specifically explores the data and gives supposedly potential ideas for the Business Stakeholders. The Business Problem that is going to be studied upon will be addressed in the next section.

# %% [markdown]
# ## BUSINESS PROBLEM

# %% [markdown]
# In this report, we will be studying the location data of a place in order to know its suitability for opening a new restaurant. Specifically, this report will be targeted to stakeholders interested in opening an restaurant in Toronto, Canada.
#
# Here in this report, we will focus on selecting the location by keeping in mind various factors by which the Stakeholders would ensure a good profit and would attract a lot of customers and thus help in a thriving business.
#
#  Since there are lots of restaurants in Toronto, we will try to detect locations that are not already crowded with restaurants. We would also prefer locations as close to city center as possible, assuming that first two conditions are met.
#
# We will all the techniques learnt throughout the course to suggest a few good and flourishing neighborhoods based on this criteria. Advantages of each area will then be clearly expressed so that best possible final location can be chosen by stakeholders.

# %% [markdown]
# ## BACKGROUND

# %% [markdown]
# Toronto is the provincial capital of Ontario. With a recorded population of 2,731,571 in 2016, it is the most populous city in Canada and the fourth most populous city in North America. The city is the anchor of the Golden Horseshoe, an urban agglomeration of 9,245,438 people (as of 2016) surrounding the western end of Lake Ontario, while the Greater Toronto Area (GTA) proper had a 2016 population of 6,417,516. Toronto is an international centre of business, finance, arts, and culture, and is recognized as one of the most multicultural and cosmopolitan cities in the world.
#
# The diverse population of Toronto reflects its current and historical role as an important destination for immigrants to Canada. More than 50 percent of residents belong to a visible minority population group, and over 200 distinct ethnic origins are represented among its inhabitants. While the majority of Torontonians speak English as their primary language, over 160 languages are spoken in the city.
#
# Toronto encompasses a geographical area formerly administered by many separate municipalities. These municipalities have each developed a distinct history and identity over the years, and their names remain in common use among Torontonians. Former municipalities include East York, Etobicoke, Forest Hill, Mimico, North York, Parkdale, Scarborough, Swansea, Weston and York. Throughout the city there exist hundreds of small neighbourhoods and some larger neighbourhoods covering a few square kilometres.
#
# Having such vast population and big geographical area, there also exists big competition between businesses. Therefore it became very challenging for stake holder or new business to decide which area they should start their business to get higher revenue with lowest possible competition.And because of its diverse ethnicity, the business should be situated in such a place that it attracts a lot of customers.
#
# ### Target Audience:
#                       New Business who wants to open a restaurant in Tornoto.
#
# This project try to solve the above problem by suggesting the Target Business stake holders the right place to open new restaurants and gaining maximum profits in Toronto.

# %% [markdown]
# ## DATA DESCRIPTION:

# %% [markdown]
#  Based on the business problem set forward, the factors that we will be considering to ensure that the restaurant is being opened in a good location are as follows:
#  - The people residing in the Neighborhood(The age group and their income)
#  - The other Restaurants situated in the specified area
#  - The Trending places in the surrounding Neighborhood that might attract people
#
# Following data sources will be needed to extract/generate the required information:
#
# - Centers of candidate areas will be generated algorithmically and approximate addresses of centers of those areas will be obtained using        https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
#
# - Number of restaurants in the neighborhood and their type and location  will be obtained using Foursquare API

# %% [markdown]
# ## METHODOLOGY

# %% [markdown]
# The ulterior motive of our study in this particular report is to find a best location for opening a new Restaurant in Toronto, one of the most populated city in Canada.
#
# So for achieving this we have put into use the data consisting of the postal codes from Toronto and the list of Restaurants situated in the respective Neighborhood.
#
# To solve the problem, we are going to cluster all the Neighborhoods in Toronto. And for this we are going to use a special Clustering "K-Means Clustering". K-means clustering is a type of unsupervised learning, which is used when you have unlabeled data (i.e., data without defined categories or groups). The goal of this algorithm is to find groups in the data, with the number of groups represented by the variable K. The algorithm works iteratively to assign each data point to one of K groups based on the features that are provided. Data points are clustered based on feature similarity. The results of the K-means clustering algorithm are:
#
# The centroids of the K clusters, which can be used to label new data Labels for the training data (each data point is assigned to a single cluster)
#
# The Folium package would be used to give visualization to all the analysis that we are carrying out by plotting all the areas into maps.
#
# The steps followed for the analysis are as follows:
#
# - Collection of Data which is required.Data: location and type (category) of every restaurant within our lat and lng. We have also the type of resutaurants in particular locality.
#
# - Explored the 'restaurant density' across different areas of Toronto - we will use K- mean to identify a few promising areas close to center with low number of restaurants and their type.
#
# - The Next step would be to make every Neighborhood onto their Clusters and take into consideration locations with less restaurants in radius of 500 meters.This would be an important factor because the business will only thrive if we ensure that the competition is less within the neighborhood.Then we will plot all the clustered Neighborhood using a map.

# %% [markdown]
# ## ANALYSIS AND RESULTS

# %% [markdown]
# #### Data identifiaction, capturing and cleaning.
#                               The first step in our analysis is to capture the Data source from the required Locations.Here we are using 2 datas, one from Wikipedia and the other from FoursquareAPI. The data about the postal codes of Canada is obtained from Wikipedia by the help of a library package named as 'BeautifulSoup'. Then we remove all the redundant value(data cleaning). Then the obtained Dataset is saved into a dataframe with three columns: Postal Code,Borough and Neighborhood. Then we combine neighborhood similar Bronx. Now the data is clean and ready to use.
#
# #### Combining different data source and sorting neighborhood based on Longitude and latitude
#                                      Now, we will combine neighborhood dataset with postal address and dataset with Latitude & Longitude and save them it separate data frame.The resultant data frame with contain details aabout Postal code, Brough, Neighborhood, Latitude & Longitude.This new Dataset is then visualized into a map.
#
# #### Explore the Toronto's neighborhoods
#             Firstly, we explored all the neighborhoods in the city of Toronto, using the Latitude & Longitude data, using Foursquare API to get the Restaurant venues available in Toronto.The dataset is cleaned to get the unique venues for each Neighborhood.We then filter out the Restaurants from the Venue details. Then we sort each Neighborhood for the top most common venues used by people.Then we find the top 10 amongst the list and leave it upto the Stakeholders for the decision.
#
# #### Clustering
#                We are clustering the city of Toronto into a cluster of five. That is the value of k will be 5. Now we use the K-Means Clustering to come up with 5 clusters in Toronto woth similar set of venues. We are going to explore each cluster based on various factors to differentiate the discriminating venie categories that explicitly differentiate each cluster. The Neighborhoods with the maximum number of Restaurants in their surrounding will be selected for further exploration.

# %% [markdown]
# ### RESULTS

# %% [markdown]
# From the analysis, we deduce the fact that although there is flood of restaurants in Toronto, there is a slight scarcity of restaurants as we move towards the city center.We have 4 boroughs and 74 neighborhoods inside geograpical coordinate of 43.653963, -79.387207.
#
# As in accordance with our assumption,the cluster with the maximum number of Restaurants in our vicinity proves a good and thriving place for a startup. Although the places with a very few restaurants may prove successful because of the less competition there, we are focussed on regions with more restaurants because of the greater probability of the restaurant becoming a success because of the population in the Neighborhood.
#
# Based on our initial assumption of the cluster with maximum number of restaurants will have the best possibility to have a new restaurant due to the need in the area. Based on the resultant clusters it looks like Cluster 1 and Cluster 5 have higher number of resturants then rest of the clusters.
#
# The Recommended places are onlt considered as the inital places which are shortlisted for anymore further analysis on a various of conditions that has to be met before the business idea is finalized. Because the Location and the competition might not be the only reasons to be doted upon.

# %% [markdown]
# ## CONCLUSION

# %% [markdown]
# The main purpose of this study was to do a complete study and to give a detailed report to the Stakeholders of the list of possible thriving and possible places so that they can narrow down their search to the list suggested. The Restaurant density Distribution that we have calculated, gives us the list of Borough which will satisfy some of the considerations and help us move further with our analysis.
#
# THe clustering of the locations are done basically to segment the entire area into seperate zones of Neighborhoods so that the analysis is easier to perform and the addresses of those zones were used as starting points for the stakeholders to begin their final search.
#
# The final decision on the location will be in the hands of the stakeholders and this decision is based on various characteristics as follows:
# - The levels of noise. For example the restaurant should not be in a place where the customers cannot eat in peace.
# - THe proximity to the major roads so that is easily commutable
# - THe real estate availability
# - The attractiveness of the Location. The location of various trending hotspots and tourist places will welcome a lot of population on a daliy basis.
# - Prices, Social and Economic dynamics of every Neighborhood.
# - The availability of resources such as water also plays important role.
#
# Our work as a data scientist is to make sure that our Stakeholders have ample data required. The list should be elaborate and clear and visually pleasing so as to allow them in making the right decision.
